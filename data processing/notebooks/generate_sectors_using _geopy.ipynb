# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time
import json

df = pd.read_pickle("df.pkl")

geolocator = Nominatim(user_agent="sector_mapper_app")

# %%
sectors = (
    df["sector"]
    .dropna()
    .astype(str)
    .str.lower()
    .str.strip()
    .unique()
)

# %%
len(sectors)
# Out:
# 353

# %%
sector_coordinates = {}

for sector in sectors:
    try:
        query = f"{sector}, Gurugram, Haryana, India"
        location = geolocator.geocode(query, timeout=10)

        if location:
            sector_coordinates[sector] = {
                "lat": round(location.latitude, 6),
                "lng": round(location.longitude, 6)
            }
            print(f"✔ {sector} added")
        else:
            print(f"❌ Not found: {sector}")

        time.sleep(1)  # IMPORTANT: avoid API blocking

    except Exception as e:
        print(f"⚠ Error for {sector}: {e}")
# Out:
# ✔ sector 36 added
# ✔ sector 89 added
# ✔ sohna road added
# ✔ sector 92 added
# ✔ sector 102 added
# ✔ gwal pahari added
# ✔ sector 108 added
# ✔ sector 105 added
# ✔ sector 26 added
# ✔ sector 109 added
# ✔ sector 28 added
# ✔ sector 65 added
# ✔ sector 12 added
# ✔ sector 85 added
# ✔ sector 70a added
# ✔ sector 30 added
# ✔ sector 107 added
# ✔ sector 3 added
# ✔ sector 2 added
# ✔ sector 41 added
# ✔ sector 4 added
# ✔ sector 62 added
# ✔ sector 49 added
# ✔ sector 81 added
# ✔ sector 66 added
# ✔ sector 86 added
# ✔ sector 104 added
# ✔ sector 48 added
# ✔ sector 51 added
# ✔ sector 37 added
# ✔ sector 111 added
# ✔ sector 67 added
# ✔ sector 113 added
# ✔ sector 13 added
# ✔ sector 61 added
# ✔ sector 69 added
# ✔ sector 67a added
# ✔ sector 37d added
# ✔ sector 82 added
# ✔ sector 53 added
# ✔ sector 74 added
# ✔ sector 52 added
# ✔ sector 43 added
# ✔ sector 14 added
# ✔ sector 25 added
# ✔ sector 95 added
# ✔ sector 56 added
# ✔ sector 83 added
# ✔ sector 88a added
# ✔ sector 55 added
# ✔ sector 50 added
# ✔ sector 84 added
# ✔ sector 91 added
# ✔ sector 76 added
# ✔ sector 82a added
# ✔ sector 78 added
# ✔ manesar added
# ✔ sector 93 added
# ✔ sector 7 added
# ✔ sector 71 added
# ✔ sector 110 added
# ✔ sector 33 added
# ✔ sector 70 added
# ✔ sector 103 added
# ✔ sector 90 added
# ✔ sector 38 added
# ✔ sector 79 added
# ✔ sector 112 added
# ✔ sector 22 added
# ✔ sector 59 added
# ✔ sector 99 added
# ✔ sector 9 added
# ✔ sector 58 added
# ✔ sector 77 added
# ✔ sector 1 added
# ✔ sector 57 added
# ✔ sector 106 added
# ✔ dwarka expressway added
# ✔ sector 63 added
# ✔ sector 5 added
# ✔ sector 40 added
# ✔ sector 23 added
# ✔ sector 6 added
# ✔ sector 72 added
# ✔ sector 47 added
# ✔ sector 45 added
# ✔ sector 68 added
# ✔ sector 11 added
# ✔ sector 60 added
# ✔ sector 39 added
# ✔ sector 63a added
# ✔ sector 24 added
# ✔ sector 46 added
# ✔ sector 17 added
# ✔ sector 15 added
# ✔ sector 10 added
# ✔ sector 31 added
# ✔ sector 21 added
# ✔ sector 80 added
# ✔ sector 73 added
# ✔ sector 54 added
# ✔ sector 8 added
# ✔ sector 88 added
# ✔ sector 27 added
# ❌ Not found: independent dlf
# ❌ Not found: m3m forestia west i
# ❌ Not found: m3mansion
# ✔ hero added
# ✔ sector 35 added
# ❌ Not found: emaar serenity hills
# ✔ sector 32 added
# ❌ Not found: ashiana mulberry
# ❌ Not found: m3m soulitude
# ❌ Not found: tulip monsella
# ❌ Not found: conscient elevate
# ❌ Not found: shapoorji pallonji dualis
# ❌ Not found: dlf arbour
# ❌ Not found: emaar greens
# ❌ Not found: ansal versalia
# ❌ Not found: conscient elaira
# ❌ Not found: satya legend
# ❌ Not found: salcon verandas
# ❌ Not found: dlf tr
# ❌ Not found: godrej meridien
# ❌ Not found: emaar urban oasis
# ❌ Not found: signature dax
# ❌ Not found: godrej miraya
# ✔ rama added
# ❌ Not found: signature de luxe dxp
# ❌ Not found: ganga kashi
# ❌ Not found: ullahawas
# ✔ dwarka expressway l added
# ❌ Not found: ansal valley view
# ❌ Not found: ashiana center court
# ✔ sector 42 added
# ❌ Not found: signature signum
# ❌ Not found: barga
# ❌ Not found: orchid ivy
# ✔ godrej summit added
# ✔ uppal southend added
# ❌ Not found: ireouptown
# ❌ Not found: urban green
# ❌ Not found: adani samsara
# ❌ Not found: jammu kashmir bank employees group hous
# ❌ Not found: eldeco fairway reserve
# ❌ Not found: tashee capital gateway
# ❌ Not found: sobha international
# ❌ Not found: godrej zenith
# ❌ Not found: smartworld sky arc
# ❌ Not found: pareena coban
# ❌ Not found: orris aster court premier
# ❌ Not found: dlf belaire
# ❌ Not found: mvn athens
# ❌ Not found: ireoskyon
# ✔ m3m flora added
# ❌ Not found: adani samsara vilasa
# ❌ Not found: piedmont taksila heights
# ❌ Not found: smartworld orchard
# ❌ Not found: dlf regency park
# ✔ signature park added
# ❌ Not found: dlf ultima
# ❌ Not found: vatika lifestyle
# ❌ Not found: unitech escape
# ✔ m3m corner walk added
# ❌ Not found: emaar palm garden
# ✔ ardee added
# ❌ Not found: raheja navodaya
# ❌ Not found: vatika xpressions
# ❌ Not found: mapsko royale ville
# ❌ Not found: signature orchard avenue
# ❌ Not found: puri emerald bay
# ❌ Not found: landmark residency
# ❌ Not found: unitech woodstock
# ❌ Not found: palatial hero
# ✔ tata primanti added
# ❌ Not found: unitech harmony
# ❌ Not found: m3m capital
# ✔ sushant lok c added
# ❌ Not found: signatureglobal titanium spr
# ✔ palam added
# ❌ Not found: unitech deerwood
# ✔ anant raj added
# ❌ Not found: ambience lagoon
# ❌ Not found: arttech story house
# ❌ Not found: ansal harmony
# ✔ shanti added
# ❌ Not found: lotus homz
# ❌ Not found: rof pyramid amaltas
# ❌ Not found: orchid garden
# ❌ Not found: pyramid fusion
# ❌ Not found: tulip infratech ace
# ✔ sushant lok added
# ❌ Not found: mk symphony
# ✔ signature added
# ❌ Not found: raheja atharva
# ❌ Not found: laxman
# ❌ Not found: emaar
# ✔ vatika added
# ❌ Not found: pratap
# ✔ jacobpura added
# ✔ signature d added
# ❌ Not found: ansal celebrity
# ❌ Not found: jms nation
# ❌ Not found: paras dews
# ✔ vatika india next added
# ❌ Not found: west rajiv
# ✔ park view added
# ✔ maruti kunj added
# ❌ Not found: puri diplomatic greens
# ❌ Not found: bella vista central park
# ✔ suncity vatsal valley added
# ❌ Not found: atskocoon
# ❌ Not found: elevate reserve
# ❌ Not found: assotech blith
# ✔ ss coralwood added
# ❌ Not found: omaxe nile
# ✔ orris carnation residency added
# ❌ Not found: ireothe corridors
# ❌ Not found: m3m antalya hills i
# ❌ Not found: jyoti park
# ❌ Not found: birla navya
# ❌ Not found: ryan enclave
# ✔ tulip ivory added
# ❌ Not found: raheja vedaanta
# ❌ Not found: unitech vistas
# ❌ Not found: spaze privvy address
# ❌ Not found: dlf express greens
# ❌ Not found: bestech altura
# ❌ Not found: signature prime
# ✔ godrej added
# ❌ Not found: aipl riviera lake
# ❌ Not found: diplomatsgolf l
# ❌ Not found: smartworld one dxp
# ❌ Not found: signature imperial
# ❌ Not found: m3m crown
# ❌ Not found: ansal height
# ❌ Not found: central park flower valley
# ✔ sector 34 added
# ❌ Not found: unitech uniworld garden
# ❌ Not found: eldeco accolade
# ❌ Not found: smartworld gems
# ✔ m3m golf hills added
# ❌ Not found: plus senate court
# ❌ Not found: atstourmal
# ❌ Not found: trehan luxury
# ❌ Not found: breez global hill view
# ✔ unitech added
# ❌ Not found: indiabulls centrum park
# ❌ Not found: shree vardhman victoria
# ❌ Not found: bptp astaire gardens
# ❌ Not found: central park cerise suites
# ✔ central park added
# ❌ Not found: m3m paragon
# ❌ Not found: suncity avenue
# ❌ Not found: spaze apotel
# ❌ Not found: dlf amaltas drive
# ❌ Not found: parsvnath green ville
# ❌ Not found: godrej air
# ✔ rail added
# ❌ Not found: orchid island
# ❌ Not found: pareena
# ❌ Not found: sweta central park
# ✔ ss l added
# ❌ Not found: godrej nature plus
# ❌ Not found: smartworld edition
# ❌ Not found: orris c greenopolis
# ❌ Not found: navraj antalyas
# ❌ Not found: sidhartha ncr one
# ✔ dlf added
# ✔ rajiv added
# ❌ Not found: vatika iris
# ❌ Not found: gls arawali
# ❌ Not found: tarc ishva
# ❌ Not found: tulip violet
# ❌ Not found: pilots court
# ❌ Not found: signature golf greens
# ❌ Not found: unitech uniworld
# ❌ Not found: tulip yellow
# ❌ Not found: emaar palm hills
# ❌ Not found: bptp green oaks
# ❌ Not found: elan presidential
# ❌ Not found: godrej frontier
# ❌ Not found: laburnum victory
# ❌ Not found: breez global heights
# ✔ huda added
# ❌ Not found: ansal sushant lok i
# ✔ joy kunj apartment added
# ✔ orris aster court added
# ❌ Not found: signature roselia
# ❌ Not found: satya merano greens
# ❌ Not found: ss almeria
# ❌ Not found: indiabulls enigma
# ❌ Not found: vatika seven lamps
# ❌ Not found: maxworth premier urban
# ✔ m3m golf added
# ❌ Not found: godrej oasis
# ❌ Not found: bestech park view residency
# ❌ Not found: rof ananda
# ❌ Not found: godrej aria
# ❌ Not found: dlf regal gardens
# ❌ Not found: shree vardhman mantra
# ❌ Not found: godrej aristocrat
# ❌ Not found: dlf garden primus
# ✔ rof aalayas added
# ✔ badshahpur added
# ✔ sapphire added
# ❌ Not found: signature andour height
# ✔ malibu added
# ❌ Not found: whitelandthe aspen
# ✔ sare crescent parc added
# ❌ Not found: emaar emerald
# ❌ Not found: experion heartsong
# ❌ Not found: ireovictory valley
# ❌ Not found: puri aravallis
# ❌ Not found: new palam
# ❌ Not found: central park resorts sky villas
# ✔ devilal added
# ❌ Not found: microtek greenburg
# ❌ Not found: rof pravasa
# ❌ Not found: godrej serenity
# ❌ Not found: sidhi v
# ❌ Not found: m3m broadway
# ❌ Not found: vista vilas
# ❌ Not found: rof alante
# ❌ Not found: ild spire greens
# ❌ Not found: signature sco
# ❌ Not found: tribeca trump tower
# ❌ Not found: elan emperor
# ❌ Not found: dlf plot
# ❌ Not found: m3mar
# ✔ dlf new heights added
# ❌ Not found: hcbs sports ville
# ❌ Not found: m3merl
# ❌ Not found: dlf skycourt
# ❌ Not found: emaar emerald hills
# ✔ old delhi added
# ✔ essel towers added
# ❌ Not found: bptp park prime
# ❌ Not found: rail classic
# ❌ Not found: bhora kalan
# ❌ Not found: vatika seven elements
# ❌ Not found: ramprastha skyz
# ❌ Not found: parkwood westend
# ❌ Not found: perfect buildwell zara aavaas
# ❌ Not found: emaar amaris
# ✔ antriksh heights added
# ✔ gpl eden heights added
# ❌ Not found: dlf grove
# ❌ Not found: suncity township
# ❌ Not found: hercules grace resilviaa
# ✔ ashok added
# ❌ Not found: alpha one
# ❌ Not found: ss cendana

# %%
print(len(sector_coordinates))
# Out:
# 158

# %%
with open("sector_coordinates.json", "w") as f:
    json.dump(sector_coordinates, f, indent=4)

# %%
# all unique sectors from dataset
all_sectors = (
    df["sector"]
    .dropna()
    .astype(str)
    .str.lower()
    .str.strip()
    .unique()
)

# sectors already mapped
mapped_sectors = set(sector_coordinates.keys())

# sectors still left
left_sectors = sorted(set(all_sectors) - mapped_sectors)

print(f"Total sectors      : {len(all_sectors)}")
print(f"Mapped sectors     : {len(mapped_sectors)}")
print(f"Left (unmapped)    : {len(left_sectors)}")

left_sectors[:10]  # preview
# Out:
# Total sectors      : 353
# Mapped sectors     : 160
# Left (unmapped)    : 193
# ['adani samsara',
#  'adani samsara vilasa',
#  'aipl riviera lake',
#  'alpha one',
#  'ambience lagoon',
#  'ansal celebrity',
#  'ansal harmony',
#  'ansal height',
#  'ansal sushant lok i',
#  'ansal valley view']

# %%
left_sectors
# Out:
# ['adani samsara',
#  'adani samsara vilasa',
#  'aipl riviera lake',
#  'alpha one',
#  'ambience lagoon',
#  'ansal celebrity',
#  'ansal harmony',
#  'ansal height',
#  'ansal sushant lok i',
#  'ansal valley view',
#  'ansal versalia',
#  'arttech story house',
#  'ashiana center court',
#  'ashiana mulberry',
#  'assotech blith',
#  'atskocoon',
#  'atstourmal',
#  'barga',
#  'bella vista central park',
#  'bestech altura',
#  'bestech park view residency',
#  'bhora kalan',
#  'birla navya',
#  'bptp astaire gardens',
#  'bptp green oaks',
#  'bptp park prime',
#  'breez global heights',
#  'breez global hill view',
#  'central park cerise suites',
#  'central park flower valley',
#  'central park resorts sky villas',
#  'conscient elaira',
#  'conscient elevate',
#  'diplomatsgolf l',
#  'dlf amaltas drive',
#  'dlf arbour',
#  'dlf belaire',
#  'dlf express greens',
#  'dlf garden primus',
#  'dlf grove',
#  'dlf regal gardens',
#  'dlf regency park',
#  'dlf skycourt',
#  'dlf tr',
#  'dlf ultima',
#  'elan emperor',
#  'elan presidential',
#  'eldeco accolade',
#  'eldeco fairway reserve',
#  'elevate reserve',
#  'emaar',
#  'emaar amaris',
#  'emaar emerald',
#  'emaar emerald hills',
#  'emaar greens',
#  'emaar palm garden',
#  'emaar palm hills',
#  'emaar serenity hills',
#  'emaar urban oasis',
#  'experion heartsong',
#  'ganga kashi',
#  'gls arawali',
#  'godrej air',
#  'godrej aria',
#  'godrej aristocrat',
#  'godrej frontier',
#  'godrej meridien',
#  'godrej miraya',
#  'godrej nature plus',
#  'godrej oasis',
#  'godrej serenity',
#  'godrej zenith',
#  'hcbs sports ville',
#  'hercules grace resilviaa',
#  'ild spire greens',
#  'independent dlf',
#  'indiabulls centrum park',
#  'indiabulls enigma',
#  'ireoskyon',
#  'ireothe corridors',
#  'ireouptown',
#  'ireovictory valley',
#  'jammu kashmir bank employees group hous',
#  'jms nation',
#  'jyoti park',
#  'laburnum victory',
#  'landmark residency',
#  'laxman',
#  'lotus homz',
#  'm3m antalya hills i',
#  'm3m broadway',
#  'm3m capital',
#  'm3m crown',
#  'm3m forestia west i',
#  'm3m paragon',
#  'm3m soulitude',
#  'm3mansion',
#  'm3mar',
#  'm3merl',
#  'mapsko royale ville',
#  'maxworth premier urban',
#  'microtek greenburg',
#  'mk symphony',
#  'mvn athens',
#  'navraj antalyas',
#  'new palam',
#  'omaxe nile',
#  'orchid garden',
#  'orchid island',
#  'orchid ivy',
#  'orris aster court premier',
#  'orris c greenopolis',
#  'palatial hero',
#  'paras dews',
#  'pareena',
#  'pareena coban',
#  'parkwood westend',
#  'parsvnath green ville',
#  'perfect buildwell zara aavaas',
#  'piedmont taksila heights',
#  'pilots court',
#  'plus senate court',
#  'puri aravallis',
#  'puri diplomatic greens',
#  'puri emerald bay',
#  'pyramid fusion',
#  'raheja atharva',
#  'raheja navodaya',
#  'raheja vedaanta',
#  'rail classic',
#  'ramprastha skyz',
#  'rof alante',
#  'rof ananda',
#  'rof pravasa',
#  'rof pyramid amaltas',
#  'ryan enclave',
#  'salcon verandas',
#  'satya legend',
#  'satya merano greens',
#  'shapoorji pallonji dualis',
#  'shree vardhman mantra',
#  'shree vardhman victoria',
#  'sidhartha ncr one',
#  'sidhi v',
#  'signature andour height',
#  'signature dax',
#  'signature de luxe dxp',
#  'signature golf greens',
#  'signature imperial',
#  'signature orchard avenue',
#  'signature prime',
#  'signature roselia',
#  'signature sco',
#  'signature signum',
#  'signatureglobal titanium spr',
#  'smartworld edition',
#  'smartworld gems',
#  'smartworld one dxp',
#  'smartworld orchard',
#  'smartworld sky arc',
#  'sobha international',
#  'spaze apotel',
#  'spaze privvy address',
#  'ss almeria',
#  'ss cendana',
#  'suncity avenue',
#  'suncity township',
#  'sweta central park',
#  'tarc ishva',
#  'tashee capital gateway',
#  'trehan luxury',
#  'tribeca trump tower',
#  'tulip infratech ace',
#  'tulip monsella',
#  'tulip violet',
#  'tulip yellow',
#  'ullahawas',
#  'unitech deerwood',
#  'unitech escape',
#  'unitech harmony',
#  'unitech uniworld',
#  'unitech uniworld garden',
#  'unitech vistas',
#  'unitech woodstock',
#  'urban green',
#  'vatika iris',
#  'vatika lifestyle',
#  'vatika seven elements',
#  'vatika seven lamps',
#  'vatika xpressions',
#  'vista vilas',
#  'west rajiv',
#  'whitelandthe aspen']

# %%
import pandas as pd

sector_df = pd.DataFrame([
    {"sector": k, "lat": v["lat"], "lon": v["lng"]}
    for k, v in sector_coordinates.items()
])

# %%
sector_df
# Out:
#                sector        lat        lon
# 0           sector 36  28.419334  76.988926
# 1           sector 89  28.418446  76.945757
# 2          sohna road  28.457201  77.028033
# 3           sector 92  28.408905  76.915523
# 4          sector 102  28.475487  76.971175
# ..                ...        ...        ...
# 153         old delhi  28.507586  77.071964
# 154      essel towers  28.476710  77.074820
# 155  antriksh heights  28.403638  76.964286
# 156  gpl eden heights  28.394500  77.021425
# 157             ashok  28.496716  77.027441
#
# [158 rows x 3 columns]

# %%
for sector in left_sectors:
    try:
        query = f"{sector}, Haryana, India"
        location = geolocator.geocode(query, timeout=10)

        if location:
            sector_coordinates[sector] = {
                "lat": round(location.latitude, 6),
                "lng": round(location.longitude, 6)
            }
            print(f"✔ {sector} added")
        else:
            print(f"❌ Not found: {sector}")

        time.sleep(1)  # IMPORTANT: avoid API blocking

    except Exception as e:
        print(f"⚠ Error for {sector}: {e}")
# Out:
# ❌ Not found: adani samsara
# ❌ Not found: adani samsara vilasa
# ❌ Not found: aipl riviera lake
# ❌ Not found: alpha one
# ❌ Not found: ambience lagoon
# ❌ Not found: ansal celebrity
# ❌ Not found: ansal harmony
# ❌ Not found: ansal height
# ❌ Not found: ansal sushant lok i
# ❌ Not found: ansal valley view
# ❌ Not found: ansal versalia
# ❌ Not found: arttech story house
# ❌ Not found: ashiana center court
# ❌ Not found: ashiana mulberry
# ❌ Not found: assotech blith
# ❌ Not found: atskocoon
# ❌ Not found: atstourmal
# ❌ Not found: barga
# ❌ Not found: bella vista central park
# ❌ Not found: bestech altura
# ❌ Not found: bestech park view residency
# ❌ Not found: bhora kalan
# ❌ Not found: birla navya
# ❌ Not found: bptp astaire gardens
# ❌ Not found: bptp green oaks
# ❌ Not found: bptp park prime
# ❌ Not found: breez global heights
# ❌ Not found: breez global hill view
# ❌ Not found: central park cerise suites
# ❌ Not found: central park flower valley
# ❌ Not found: central park resorts sky villas
# ❌ Not found: conscient elaira
# ❌ Not found: conscient elevate
# ❌ Not found: diplomatsgolf l
# ❌ Not found: dlf amaltas drive
# ❌ Not found: dlf arbour
# ❌ Not found: dlf belaire
# ❌ Not found: dlf express greens
# ❌ Not found: dlf garden primus
# ❌ Not found: dlf grove
# ✔ dlf plot added
# ❌ Not found: dlf regal gardens
# ❌ Not found: dlf regency park
# ❌ Not found: dlf skycourt
# ❌ Not found: dlf tr
# ❌ Not found: dlf ultima
# ❌ Not found: elan emperor
# ❌ Not found: elan presidential
# ❌ Not found: eldeco accolade
# ❌ Not found: eldeco fairway reserve
# ❌ Not found: elevate reserve
# ❌ Not found: emaar
# ❌ Not found: emaar amaris
# ❌ Not found: emaar emerald
# ❌ Not found: emaar emerald hills
# ❌ Not found: emaar greens
# ❌ Not found: emaar palm garden
# ❌ Not found: emaar palm hills
# ❌ Not found: emaar serenity hills
# ❌ Not found: emaar urban oasis
# ❌ Not found: experion heartsong
# ❌ Not found: ganga kashi
# ❌ Not found: gls arawali
# ❌ Not found: godrej air
# ❌ Not found: godrej aria
# ❌ Not found: godrej aristocrat
# ❌ Not found: godrej frontier
# ❌ Not found: godrej meridien
# ❌ Not found: godrej miraya
# ❌ Not found: godrej nature plus
# ❌ Not found: godrej oasis
# ❌ Not found: godrej serenity
# ❌ Not found: godrej zenith
# ❌ Not found: hcbs sports ville
# ❌ Not found: hercules grace resilviaa
# ❌ Not found: ild spire greens
# ❌ Not found: independent dlf
# ❌ Not found: indiabulls centrum park
# ❌ Not found: indiabulls enigma
# ❌ Not found: ireoskyon
# ❌ Not found: ireothe corridors
# ❌ Not found: ireouptown
# ❌ Not found: ireovictory valley
# ❌ Not found: jammu kashmir bank employees group hous
# ❌ Not found: jms nation
# ❌ Not found: jyoti park
# ❌ Not found: laburnum victory
# ❌ Not found: landmark residency
# ❌ Not found: laxman
# ❌ Not found: lotus homz
# ❌ Not found: m3m antalya hills i
# ❌ Not found: m3m broadway
# ❌ Not found: m3m capital
# ❌ Not found: m3m crown
# ❌ Not found: m3m forestia west i
# ❌ Not found: m3m paragon
# ❌ Not found: m3m soulitude
# ❌ Not found: m3mansion
# ❌ Not found: m3mar
# ❌ Not found: m3merl
# ❌ Not found: mapsko royale ville
# ❌ Not found: maxworth premier urban
# ❌ Not found: microtek greenburg
# ❌ Not found: mk symphony
# ❌ Not found: mvn athens
# ❌ Not found: navraj antalyas
# ❌ Not found: new palam
# ❌ Not found: omaxe nile
# ❌ Not found: orchid garden
# ❌ Not found: orchid island
# ❌ Not found: orchid ivy
# ❌ Not found: orris aster court premier
# ❌ Not found: orris c greenopolis
# ❌ Not found: palatial hero
# ❌ Not found: paras dews
# ❌ Not found: pareena
# ❌ Not found: pareena coban
# ❌ Not found: parkwood westend
# ❌ Not found: parsvnath green ville
# ❌ Not found: perfect buildwell zara aavaas
# ❌ Not found: piedmont taksila heights
# ❌ Not found: pilots court
# ❌ Not found: plus senate court
# ✔ pratap added
# ❌ Not found: puri aravallis
# ❌ Not found: puri diplomatic greens
# ❌ Not found: puri emerald bay
# ❌ Not found: pyramid fusion
# ❌ Not found: raheja atharva
# ❌ Not found: raheja navodaya
# ❌ Not found: raheja vedaanta
# ❌ Not found: rail classic
# ❌ Not found: ramprastha skyz
# ❌ Not found: rof alante
# ❌ Not found: rof ananda
# ❌ Not found: rof pravasa
# ❌ Not found: rof pyramid amaltas
# ❌ Not found: ryan enclave
# ❌ Not found: salcon verandas
# ❌ Not found: satya legend
# ❌ Not found: satya merano greens
# ❌ Not found: shapoorji pallonji dualis
# ❌ Not found: shree vardhman mantra
# ❌ Not found: shree vardhman victoria
# ❌ Not found: sidhartha ncr one
# ❌ Not found: sidhi v
# ❌ Not found: signature andour height
# ❌ Not found: signature dax
# ❌ Not found: signature de luxe dxp
# ❌ Not found: signature golf greens
# ❌ Not found: signature imperial
# ❌ Not found: signature orchard avenue
# ❌ Not found: signature prime
# ❌ Not found: signature roselia
# ❌ Not found: signature sco
# ❌ Not found: signature signum
# ❌ Not found: signatureglobal titanium spr
# ❌ Not found: smartworld edition
# ❌ Not found: smartworld gems
# ❌ Not found: smartworld one dxp
# ❌ Not found: smartworld orchard
# ❌ Not found: smartworld sky arc
# ❌ Not found: sobha international
# ❌ Not found: spaze apotel
# ❌ Not found: spaze privvy address
# ❌ Not found: ss almeria
# ❌ Not found: ss cendana
# ❌ Not found: suncity avenue
# ❌ Not found: suncity township
# ❌ Not found: sweta central park
# ❌ Not found: tarc ishva
# ❌ Not found: tashee capital gateway
# ❌ Not found: trehan luxury
# ❌ Not found: tribeca trump tower
# ❌ Not found: tulip infratech ace
# ❌ Not found: tulip monsella
# ❌ Not found: tulip violet
# ❌ Not found: tulip yellow
# ❌ Not found: ullahawas
# ❌ Not found: unitech deerwood
# ❌ Not found: unitech escape
# ❌ Not found: unitech harmony
# ❌ Not found: unitech uniworld
# ❌ Not found: unitech uniworld garden
# ❌ Not found: unitech vistas
# ❌ Not found: unitech woodstock
# ❌ Not found: urban green
# ❌ Not found: vatika iris
# ❌ Not found: vatika lifestyle
# ❌ Not found: vatika seven elements
# ❌ Not found: vatika seven lamps
# ❌ Not found: vatika xpressions
# ❌ Not found: vista vilas
# ❌ Not found: west rajiv
# ❌ Not found: whitelandthe aspen

# %%
freq_map = (
    df["sector"]
    .astype(str)
    .str.lower()
    .str.strip()
    .value_counts()
    .loc[list(mapped_sectors)]
    .reset_index()
)

freq_map.columns = ["sector", "frequency"]

# %%
freq = (
    df["sector"]
    .astype(str)
    .str.lower()
    .str.strip()
    .value_counts()
    .loc[left_sectors]
    .reset_index()
)

freq.columns = ["sector", "frequency"]
# Out:
#                    sector  frequency
# 0           adani samsara          1
# 1    adani samsara vilasa          2
# 2       aipl riviera lake          1
# 3               alpha one          1
# 4         ambience lagoon          2
# ..                    ...        ...
# 188    vatika seven lamps          1
# 189     vatika xpressions          1
# 190           vista vilas          1
# 191            west rajiv          1
# 192    whitelandthe aspen          2
#
# [193 rows x 2 columns]

# %%
freq.sort_values(by='frequency',ascending=False)['frequency']
# Out:
# 71     5
# 158    5
# 66     4
# 68     4
# 156    4
#       ..
# 80     1
# 81     1
# 82     1
# 83     1
# 96     1
# Name: frequency, Length: 193, dtype: int64

# %%
freq_map.sort_values(by='frequency',ascending=False)['frequency'].sum()
# Out:
# 5784

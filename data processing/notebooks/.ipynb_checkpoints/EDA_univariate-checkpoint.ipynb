# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\VICTUS\Downloads\gurgaon_properties_cleaned_v2.csv")
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3803 entries, 0 to 3802
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3803 non-null   object
#  1   society              3802 non-null   object
#  2   sector               3803 non-null   object
#  3   price                3785 non-null   float64
#  4   price_per_sqft       3785 non-null   float64
#  5   area                 3785 non-null   float64
#  6   areaWithType         3803 non-null   object
#  7   bedRoom              3803 non-null   int64
#  8   bathroom             3803 non-null   int64
#  9   balcony              3803 non-null   object
#  10  floorNum             3784 non-null   float64
#  11  facing               2698 non-null   object
#  12  agePossession        3803 non-null   object
#  13  super_built_up_area  1915 non-null   float64
#  14  built_up_area        1733 non-null   float64
# ...

# %%
df.duplicated().sum()
# Out:
# 126

# %%
df.drop_duplicates(inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Property_Type

# %%
sns.countplot(df['property_type'])
# Out:
# <Axes: xlabel='count', ylabel='property_type'>

# %% [markdown]
# ### description
# - Majority data is of flats 75%
# - NO missing values

# %% [markdown]
# # Society

# %%
df['society'].value_counts(normalize=True).cumsum().head(75)
# Out:
# society
# independent                             0.132209
# tulip violet                            0.152612
# ss the leaf                             0.172470
# dlf new town heights                    0.183896
# shapoorji pallonji joyville gurugram    0.195321
#                                           ...
# the close north                         0.554135
# ramsons kshitij                         0.557671
# umang monsoon breeze                    0.561208
# ats kocoon                              0.564744
# ireo the corridors                      0.568009
# Name: proportion, Length: 75, dtype: float64

# %%
society_counts = df['society'].value_counts()

# Frequency distribution for societies
frequency_bins = {
    "Very High (>100)": (society_counts > 100).sum(),
    "High (50-100)": ((society_counts >= 50) & (society_counts <= 100)).sum(),
    "Average (10-49)": ((society_counts >= 10) & (society_counts < 50)).sum(),
    "Low (2-9)": ((society_counts > 1) & (society_counts < 10)).sum(),
    "Very Low (1)": (society_counts == 1).sum()
}
frequency_bins
# Out:
# {'Very High (>100)': 1,
#  'High (50-100)': 2,
#  'Average (10-49)': 92,
#  'Low (2-9)': 273,
#  'Very Low (1)': 308}

# %%
soc=df['society'].value_counts().head(10)
plt.bar(soc.index,soc.values)
plt.xticks(rotation=90)
plt.show()

# %%
df[df['society'].isnull()]
# Out:
#      property_type society     sector  price  price_per_sqft    area  \
# 2693          flat     NaN  sector 78    0.6          3692.0  1625.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2693  Built Up area: 1625 (150.97 sq.m.)        2         2       0       NaN
#
#      facing       agePossession  super_built_up_area  built_up_area  \
# 2693    NaN  Under Construction                  NaN         1625.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2693          NaN           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 2693                0             0

# %% [markdown]
# ### description
# - large no of classes in society
# - 75 society contain 56% of data.
# - approx 400 independent
# - Very High (>100): Only 1 society has more than 100 listings.
# - High (50-100): 2 societies have between 50 to 100 listings.
# - Average (10-49): 92 societies fall in this range with 10 to 49 listings each.
# - Low (2-9): 273 societies have between 2 to 9 listings.
# - Very Low (1): A significant number, 308 societies, have only 1 listing.
# - 1 missing value

# %% [markdown]
# # Sector

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road    166
# sector 85     108
# sector 102    107
# sector 92     100
# sector 69      93
#              ...
# sector 30       5
# sector 80       5
# sector 73       3
# sector 88       3
# sector 27       3
# Name: count, Length: 104, dtype: int64

# %%
df['sector'].value_counts(normalize=True).cumsum().head(30)
# Out:
# sector
# sohna road    0.045145
# sector 85     0.074517
# sector 102    0.103617
# sector 92     0.130813
# sector 69     0.156106
# sector 90     0.180310
# sector 81     0.203971
# sector 65     0.227631
# sector 109    0.251020
# sector 79     0.271689
# sector 104    0.290454
# sector 33     0.309219
# sector 83     0.327713
# sector 43     0.345390
# sector 50     0.362796
# sector 86     0.380201
# sector 37d    0.397335
# sector 95     0.414196
# sector 2      0.431058
# sector 107    0.447376
# sector 108    0.463421
# sector 89     0.478923
# sector 56     0.494153
# sector 48     0.509111
# sector 70a    0.523797
# sector 37     0.537939
# sector 26     0.551537
# sector 70     0.565135
# sector 4      0.578461
# sector 84     0.591787
# Name: proportion, dtype: float64

# %%
sec=df['sector'].value_counts().head(10)
plt.bar(sec.index,sec.values)
plt.xticks(rotation=90)
plt.show()

# %%
# Frequency distribution for sectors
sector_counts = df['sector'].value_counts()

sector_frequency_bins = {
    "Very High (>100)": (sector_counts > 100).sum(),
    "High (50-100)": ((sector_counts >= 50) & (sector_counts <= 100)).sum(),
    "Average (10-49)": ((sector_counts >= 10) & (sector_counts < 50)).sum(),
    "Low (2-9)": ((sector_counts > 1) & (sector_counts < 10)).sum(),
    "Very Low (1)": (sector_counts == 1).sum()
}

sector_frequency_bins
# Out:
# {'Very High (>100)': 3,
#  'High (50-100)': 25,
#  'Average (10-49)': 60,
#  'Low (2-9)': 16,
#  'Very Low (1)': 0}

# %% [markdown]
# ### Observations
# - There are a total of 104 unique sectors in the dataset.
# - Frequency distribution of sectors:
# - Very High (>100): 3 sectors have more than 100 listings.
# - High (50-100): 25 sectors have between 50 to 100 listings.
# - Average (10-49): A majority, 60 sectors, fall in this range with 10 to 49 listings each.
# - Low (2-9): 16 sectors have between 2 to 9 listings.
# - Very Low (1): Interestingly, there are no sectors with only 1 listing.
# - 30 sectors contain 60% data

# %% [markdown]
# # Price

# %%
df['price'].isnull().sum()
# Out:
# 17

# %%
df['price'].describe()
# Out:
# count    3660.000000
# mean        2.533664
# std         2.980623
# min         0.070000
# 25%         0.950000
# 50%         1.520000
# 75%         2.750000
# max        31.500000
# Name: price, dtype: float64

# %%
sns.kdeplot(data=df,x=df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(data=df,x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
df[df['price']>5].shape[0]
# Out:
# 447

# %%
# Skewness and Kurtosis
skewness = df['price'].skew()
kurtosis = df['price'].kurt()

print(skewness,kurtosis)
# Out:
# 3.2791704733134623 14.933372629214258

# %%
# Quantile Analysis
quantiles = df['price'].quantile([0.01, 0.05, 0.95, 0.99])

quantiles
# Out:
# 0.01     0.250
# 0.05     0.370
# 0.95     8.500
# 0.99    15.264
# Name: price, dtype: float64

# %%
# Identify potential outliers using IQR method
Q1 = df['price'].describe()['25%']
Q3 = df['price'].describe()['75%']
IQR = Q3 - Q1

IQR
# Out:
# 1.8

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound, upper_bound)
# Out:
# -1.7500000000000002 5.45

# %%
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
outliers.shape
# Out:
# (425, 23)

# %%
outliers['price'].describe()
# Out:
# count    425.000000
# mean       9.235624
# std        4.065259
# min        5.460000
# 25%        6.460000
# 50%        8.000000
# 75%       10.750000
# max       31.500000
# Name: price, dtype: float64

# %% [markdown]
# Outliers Analysis (using IQR method):
#
# * Based on the IQR method, there are 425 properties considered as outliers.
# * These outliers have an average price of approximately 9.24 crores.
# * The range for these outliers is from 5.46 crores to 31.5 crores.

# %%
bins = [0, 1, 2, 3, 5, 10, 20, 50]
bin_labels = ["0-1", "1-2", "2-3", "3-5", "5-10", "10-20", "20-50"]
pd.cut(df['price'], bins=bins, labels=bin_labels, right=False).value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.histplot(df['price'], kde=True, bins=50, color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.histplot(np.log1p(df['price']), kde=True, bins=50, color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.boxplot(df['price'], color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.boxplot(np.log1p(df['price']), color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # price_per_sqrt

# %%
df['price_per_sqft'].isnull().sum()
# Out:
# 17

# %%
df['price_per_sqft'].describe()
# Out:
# count      3660.000000
# mean      13892.668306
# std       23210.067190
# min           4.000000
# 25%        6817.250000
# 50%        9020.000000
# 75%       13880.500000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
sns.kdeplot(data=df,x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %% [markdown]
# Most properties have a price_per_sqft ranging between approximately ₹0 and ₹40,000. There is a significant concentration in the lower range, with a few properties having exceptionally high price_per_sqft.

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %% [markdown]
# The box plot clearly shows several outliers, especially on the higher side. The interquartile range (IQR) is relatively compact, but there are many data points beyond the "whiskers" of the box plot, indicating potential outliers
#
# Observations
# - Potential Outliers
# - Right Skewed
# - 17 missing values

# %% [markdown]
# # bedroom

# %%
df['bedRoom'].isnull().sum()
# Out:
# 0

# %%
df['bedRoom'].value_counts(normalize=True).cumsum()
# Out:
# bedRoom
# 3     0.406853
# 2     0.663041
# 4     0.842535
# 5     0.899646
# 1     0.933370
# 6     0.953495
# 9     0.964645
# 8     0.972804
# 12    0.980419
# 7     0.988034
# 10    0.993473
# 16    0.996736
# 13    0.997824
# 18    0.998368
# 19    0.998912
# 11    0.999184
# 20    0.999456
# 14    0.999728
# 21    1.000000
# Name: proportion, dtype: float64

# %%
sns.barplot(x=df['bedRoom'].value_counts().index,y=df['bedRoom'].value_counts().values)
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].value_counts().head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # bathroom

# %%
df['bathroom'].isnull().sum()
# Out:
# 0

# %%
df['bathroom'].value_counts(normalize=True).cumsum()
# Out:
# bathroom
# 3     0.292902
# 2     0.577645
# 4     0.800653
# 5     0.880609
# 1     0.923035
# 6     0.954855
# 9     0.966005
# 7     0.976883
# 8     0.983682
# 12    0.989665
# 10    0.992113
# 16    0.994289
# 11    0.995377
# 18    0.996465
# 13    0.997552
# 17    0.998368
# 20    0.999184
# 14    0.999728
# 21    1.000000
# Name: proportion, dtype: float64

# %%
sns.barplot(x=df['bathroom'].value_counts().index,y=df['bathroom'].value_counts().values)
# Out:
# <Axes: xlabel='bathroom'>

# %%
df['bathroom'].value_counts().head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # balcony

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'].value_counts(normalize=True).cumsum()
# Out:
# balcony
# 3+    0.318738
# 3     0.610824
# 2     0.851237
# 1     0.950503
# 0     1.000000
# Name: proportion, dtype: float64

# %%
sns.barplot(x=df['balcony'].value_counts().index,y=df['balcony'].value_counts().values)
# Out:
# <Axes: xlabel='balcony'>

# %%
df['balcony'].value_counts().head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # floorNum

# %%
df['floorNum'].isnull().sum()
# Out:
# 19

# %%
df['floorNum'].describe()
# Out:
# count    3658.000000
# mean        6.798250
# std         6.012454
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%        10.000000
# max        51.000000
# Name: floorNum, dtype: float64

# %%
sns.kdeplot(df['floorNum'
             ])
# Out:
# <Axes: xlabel='floorNum', ylabel='Density'>

# %%
sns.boxplot(df['floorNum'
             ])
# Out:
# <Axes: ylabel='floorNum'>

# %% [markdown]
# - The majority of the properties lie between the ground floor (0) and the 25th floor.
# - Floors 1 to 4 are particularly common, with the 3rd floor being the most frequent.
# - There are a few properties located at higher floors, but their frequency is much lower.
# - The box plot reveals that the majority of the properties are concentrated around the lower floors.
# - The interquartile range (IQR) lies between approximately the 2nd and 10th floors.
# - Data points beyond the "whiskers" of the box plot, especially on the higher side, indicate potential outliers.

# %% [markdown]
# # facing

# %%
df['facing'].isnull().sum()
# Out:
# 1045

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_234644\3692945726.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            1045
# North-East     623
# East           623
# North          387
# West           249
# South          231
# North-West     193
# South-East     173
# South-West     153
# Name: count, dtype: int64

# %% [markdown]
# # agePossession

# %%
df['agePossession'].isnull().sum()
# Out:
# 0

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1646
# New Property           593
# Moderately Old         563
# Undefined              306
# Old Property           303
# Under Construction     266
# Name: count, dtype: int64

# %%
sns.countplot(df['agePossession'])
# Out:
# <Axes: xlabel='count', ylabel='agePossession'>

# %% [markdown]
# # areas

# %%
# super built up area
df['super_built_up_area'].isnull().sum()
# Out:
# 1802

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
sns.kdeplot(df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(df['super_built_up_area'])
# Out:
# <Axes: ylabel='super_built_up_area'>

# %% [markdown]
# - Most properties have a super built-up area ranging between approximately 1,000 sq.ft and 2,500 sq.ft.
# - There are a few properties with a significantly larger area, leading to a right-skewed distribution.
# - The interquartile range (IQR) lies between roughly 1,480 sq.ft and 2,215 sq.ft, indicating that the middle 50% of the properties fall within this range.
# - There are several data points beyond the upper "whisker" of the box plot, indicating potential outliers.
# - These are properties with an unusually large super built-up area.

# %%
# built up area
df['built_up_area'].isnull().sum()
# Out:
# 1987

# %%
df['built_up_area'].describe()
# Out:
# count      1690.000000
# mean       2379.585816
# std       17942.880237
# min           2.000000
# 25%        1100.000000
# 50%        1650.000000
# 75%        2400.000000
# max      737147.000000
# Name: built_up_area, dtype: float64

# %%
sns.boxplot(df['built_up_area'])
# Out:
# <Axes: ylabel='built_up_area'>

# %%
sns.boxplot(df[df['built_up_area']!=737147.000000]['built_up_area'])
# Out:
# <Axes: ylabel='built_up_area'>

# %% [markdown]
# - Most properties have a built-up area ranging roughly between 500 sq.ft and 3,500 sq.ft.
# - There are very few properties with a much larger built-up area, leading to a highly right-skewed distribution.
# - The box plot confirms the presence of significant outliers on the higher side. The data's interquartile range (IQR) is relatively compact, but the "whiskers" of the box plot are stretched due to the outliers.
# - The presence of extreme values, especially on the higher side, suggests that there may be outliers or data errors.
# -  This could also be due to some properties being exceptionally large, like a commercial complex or an entire building being listed.

# %%
# carpet area
df['carpet_area'].isnull().sum()
# Out:
# 1805

# %%
df['carpet_area'].describe()
# Out:
# count      1872.000000
# mean       2529.179507
# std       22799.836449
# min          15.000000
# 25%         843.000000
# 50%        1300.000000
# 75%        1790.000000
# max      607936.000000
# Name: carpet_area, dtype: float64

# %%
sns.boxplot(df['carpet_area'])
# Out:
# <Axes: ylabel='carpet_area'>

# %% [markdown]
# # additional rooms

# %%
plt.figure(figsize=(20, 12))

# Create a subplot of pie charts for each room type
for idx, room in enumerate(['study room','servant room','store room','pooja room','others'], 1):
    ax = plt.subplot(2, 3, idx)
    df[room].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, ax=ax)
    plt.title(f'Distribution of {room.title()}')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# # furnishing_type

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 0    2411
# 1    1059
# 2     207
# Name: count, dtype: int64

# %%
df['furnishing_type'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# luxury score

# %%
df['luxury_score'].isnull().sum()
# Out:
# 0

# %%
df['luxury_score'].describe()
# Out:
# count    3677.000000
# mean       71.512918
# std        53.059082
# min         0.000000
# 25%        31.000000
# 50%        59.000000
# 75%       110.000000
# max       174.000000
# Name: luxury_score, dtype: float64

# %%
sns.kdeplot(df['luxury_score'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %% [markdown]
# - The luxury score distribution has multiple peaks, suggesting a multi-modal distribution.
# - There's a significant number of properties with lower luxury scores (around 0-50), and another peak is observed around the 110-130 range.
#
# - The box plot reveals that the majority of the properties have luxury scores between approximately 30 and 110. The interquartile range (IQR) lies between these values.

# %%
sns.boxplot(df['luxury_score'], color='lightgreen')
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# ...
